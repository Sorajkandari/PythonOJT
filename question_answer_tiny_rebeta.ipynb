# %%
#importing file from google drive


import pandas as pd

from google.colab import drive
drive.mount('/content/drive/')

df = pd.read_csv("/content/drive/MyDrive/python practice /ProductDes.csv")

print(df.shape)
df2 = df
# Out:
# Mounted at /content/drive/
# (50000, 4)

# %%
display(df)
# Out:
#        Unnamed: 0  PC_ITEM_ID  \
# 0               0    10235385
# 1               1    87834832
# 2               2        6301
# 3               3        6298
# 4               4        6305
# ...           ...         ...
# 49995       49995    10365456
# 49996       49996    48137535
# 49997       49997   143209480
# 49998       49998   146447702
# 49999       49999   143700516
#
#                                             PC_ITEM_NAME  \
# 0                                 Indigo/ Esteem on Rent
# 1                                             Henna Cone
# 2                         PB TRINITY POSTAL DOOR KNOCKER
# 3                              PB LION HEAD DOOR KNOCKER
# 4                                           Mortice Knob
# ...                                                  ...
# 49995                                    Premium Saddles
# 49996         Spargz Rhodium Plated Necklace Earring Set
# 49997                                Electric Tray Dryer
# ...

# %%
display(df2)
# Out:
#        Unnamed: 0  PC_ITEM_ID  \
# 0               0    10235385
# 1               1    87834832
# 2               2        6301
# 3               3        6298
# 4               4        6305
# ...           ...         ...
# 49995       49995    10365456
# 49996       49996    48137535
# 49997       49997   143209480
# 49998       49998   146447702
# 49999       49999   143700516
#
#                                             PC_ITEM_NAME  \
# 0                                 Indigo/ Esteem on Rent
# 1                                             Henna Cone
# 2                         PB TRINITY POSTAL DOOR KNOCKER
# 3                              PB LION HEAD DOOR KNOCKER
# 4                                           Mortice Knob
# ...                                                  ...
# 49995                                    Premium Saddles
# 49996         Spargz Rhodium Plated Necklace Earring Set
# 49997                                Electric Tray Dryer
# ...

# %%
df2 = df2.iloc[:1000]
print(df2.shape)
# Out:
# (1000, 4)

# %%
print(df3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-22f43744405f> in <module>
# ----> 1 print(df3)
#
# NameError: name 'df3' is not defined

# %%
# !pip install transformers
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

model_name = "deepset/tinyroberta-squad2"


# b) Load model & tokenizer
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.9 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 163 kB 50.8 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 30.9 MB/s
# ...
# Downloading:   0%|          | 0.00/835 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/326M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/383 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
# for row in df3.itertuples():
#     print(row)

# %%
def remove_html_tags(text):
    """Remove html tags from a string"""
    import re
    CLEANR = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    return re.sub(CLEANR, '', text)

# %%
df2['PC_ITEM_DESC_SMALL'] = df2['PC_ITEM_DESC_SMALL'].apply(remove_html_tags)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e7b9b0ad7091> in <module>
# ----> 1 df2['PC_ITEM_DESC_SMALL'] = df2['PC_ITEM_DESC_SMALL'].apply(remove_html_tags)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# ...

# %%
item = "Size: 280x55mm"
print("PRODUCT DESCRIPTION",end='\n')
print(item, end = '\n')

nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
QA_input = {
    'question': input(),
    'context': item
}
res = nlp(QA_input)
print(res)

# %%
# for item in df3.itertuples():
#     print(item[1])

# %%
# a) Get predictions

for item in df3.itertuples():
    while(1):
        print("PRODUCT DESCRIPTION",end='\n')
        print(item, end = '\n')

        nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
        QA_input = {
            'question': str(input()),
            'context': item[1]
        }
        res = nlp(QA_input)
        print(res)
        print("FOR NEXT PRODUCT DESCRIPTION PRESS 1",end = '\n')
        x  = int(input())
        if(x == 1):
            break;
        else: 
            continue

# %% [markdown]
# ANOTHER METHOD USING PRODUCT DESCP ID

# %%
display(df)

# %%
item = int(input("Enter pc item id\n"))

d = df[df['PC_ITEM_ID'] == item]['PC_ITEM_DESC_SMALL'].values[0]

# %%
print(d)

# %%
tags = ['color?','size?','company?','price?','location?']

# %%
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
QA_input = {
    'question': tags[0],
    'context': d
}
res = nlp(QA_input)
print(res)
QA_input = {
    'question': tags[1],
    'context': d
}
res = nlp(QA_input)
print(res)
QA_input = {
    'question': tags[2],
    'context': d
}
res = nlp(QA_input)
print(res)
QA_input = {
    'question': tags[3],
    'context': d
}
res = nlp(QA_input)
print(res)
QA_input = {
    'question': tags[4],
    'context': d
}
res = nlp(QA_input)
print(res)
